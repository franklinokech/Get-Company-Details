# %% [markdown]
# <a href="https://colab.research.google.com/github/franklinokech/Get-Company-Details/blob/main/Get_Companies_Details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
table_companies = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_companies_of_Kenya',
    match='Notable companies',
)
print(f'Total tables: {len(table_companies)}')
# Out:
# Total tables: 1

# %%
# select table
df = table_companies[0]
df
# Out:
#                                     Name  ...                                              Notes
# 0                        98.4 Capital FM  ...                                              Radio
# 1                               ABC Bank  ...                                    Commercial bank
# 2        ALS – Aircraft Leasing Services  ...                                   Regional airline
# 3                     ARM Cement Limited  ...     Cement, fertilizers, minerals, mining, KN: ARM
# 4                         Bamburi Cement  ...                                   Cement, KN: BAMB
# 5                   Carbacid Investments  ...                           Carbon dioxide, KN: CARB
# 6               Chase Bank Kenya Limited  ...                                    Commercial bank
# 7                           CMC Aviation  ...                      Charter airline, defunct 2011
# 8              Commercial Bank of Africa  ...                                    Commercial bank
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          40 non-null     object
#  1   Industry      40 non-null     object
#  2   Sector        40 non-null     object
#  3   Headquarters  40 non-null     object
#  4   Founded       40 non-null     object
#  5   Notes         40 non-null     object
# dtypes: object(6)
# memory usage: 2.0+ KB
